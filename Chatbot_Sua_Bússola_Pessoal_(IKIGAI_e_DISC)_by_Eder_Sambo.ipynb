# %% [markdown]
# <a href="https://colab.research.google.com/github/egsambo/cursoalura/blob/master/Chatbot_Sua_B%C3%BAssola_Pessoal_(IKIGAI_e_DISC)_by_Eder_Sambo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Chatbot_IKIGAI_DISC_v4_HTML.ipynb

Automatically generated by Colab.

## Chatbot para Propósito de Vida (IKIGAI) e Perfil Comportamental (DISC) com Interface HTML
"""

from IPython.display import display, HTML, clear_output

# Funções auxiliares para estilização e re-uso de HTML
def display_html(html_content):
    """Limpa a saída anterior e exibe o novo conteúdo HTML."""
    # clear_output(wait=True) # Descomente se quiser limpar a célula inteira a cada display
    display(HTML(html_content))

def styled_text(text, size="16px", color="#333", weight="normal", margin_bottom="10px"):
    return f"<p style='font-size:{size}; color:{color}; font-weight:{weight}; margin-bottom:{margin_bottom};'>{text}</p>"

def styled_title(text, level="h2", color="#007bff", margin_top="20px", margin_bottom="15px"):
    return f"<{level} style='color:{color}; margin-top:{margin_top}; margin-bottom:{margin_bottom}; border-bottom: 2px solid {color}; padding-bottom: 5px;'>{text}</{level}>"

def styled_question_group(question_text, options_dict):
    options_html = "<ul style='list-style-type: none; padding-left: 0;'>"
    for key, (desc, _) in options_dict.items():
        options_html += f"<li style='margin-bottom: 8px;'><strong>{key.upper()})</strong> {desc}</li>"
    options_html += "</ul>"
    return f"""
    <div style='background-color: #f9f9f9; border: 1px solid #eee; border-radius: 8px; padding: 15px; margin-bottom: 20px;'>
        <h4 style='color: #555; margin-top:0; margin-bottom:10px;'>{question_text}</h4>
        {options_html}
    </div>
    """

def styled_section_break():
    return "<hr style='border: 0; border-top: 1px solid #ccc; margin: 30px 0;'>"

def get_user_input(prompt_message):
    """Exibe uma mensagem HTML e depois usa input() padrão."""
    display_html(f"<p style='font-weight:bold; color:#5cb85c; margin-top:10px;'>{prompt_message}</p>")
    return input()


def exibir_boas_vindas():
    """Exibe a mensagem de boas-vindas ao usuário com HTML."""
    html_content = """
    <div style='background-color: #e7f3fe; border-left: 6px solid #2196F3; padding: 20px; margin-bottom: 20px; border-radius: 5px;'>
        <h1 style='color: #1976D2; margin-top:0;'>🌟 Bem-vindo(a) ao Assistente de Autoconhecimento! 🌟</h1>
        <p style='font-size: 18px; color: #333;'>Olá! Estou aqui para te ajudar a refletir sobre seu <strong>propósito de vida (IKIGAI)</strong>
        e a identificar seu <strong>perfil comportamental (DISC)</strong>.</p>
        <p style='font-size: 16px; color: #555;'>Vamos começar essa jornada juntos?</p>
    </div>
    """
    display_html(html_content)

def exibir_menu_principal():
    """Exibe o menu principal com HTML e obtém a escolha do usuário."""
    html_content = styled_title("Como posso te ajudar hoje?", level="h2", color="#ff9800")
    html_content += """
    <ul style='list-style-type: none; padding-left: 0; font-size: 18px;'>
        <li style='margin-bottom: 10px; background-color:#f0f0f0; padding:10px; border-radius:5px;'><strong>1.</strong> 🧘 Encontrar meu IKIGAI (Propósito de Vida)</li>
        <li style='margin-bottom: 10px; background-color:#f0f0f0; padding:10px; border-radius:5px;'><strong>2.</strong> 🧠 Descobrir meu Perfil Comportamental (DISC)</li>
        <li style='margin-bottom: 10px; background-color:#f0f0f0; padding:10px; border-radius:5px;'><strong>3.</strong> 👋 Sair</li>
    </ul>
    """
    display_html(html_content)
    while True:
        try:
            escolha = int(get_user_input("Digite o número da sua escolha (1, 2 ou 3):"))
            if escolha in [1, 2, 3]:
                return escolha
            else:
                display_html(styled_text("Opção inválida. Por favor, escolha 1, 2 ou 3.", color="red"))
        except ValueError:
            display_html(styled_text("Entrada inválida. Por favor, digite um número.", color="red"))

def modulo_ikigai():
    """Conduz o usuário através do processo de reflexão do IKIGAI com HTML."""
    clear_output(wait=True)
    display_html(styled_title("🧘 Explorando seu IKIGAI 🧘", level="h1", color="#4CAF50"))
    display_html(styled_text("IKIGAI é um conceito japonês que significa 'a razão de ser' ou 'o motivo para acordar todos os dias'.<br>Vamos refletir sobre quatro áreas importantes da sua vida.", size="17px"))

    respostas_ikigai = {}
    ikigai_perguntas = [
        ("O QUE VOCÊ AMA FAZER? ❤️", "Pense em atividades que te trazem alegria, paixão e que você faria mesmo que não fosse pago."),
        ("NO QUE VOCÊ É BOM? 💪", "Quais são seus talentos naturais, habilidades que você desenvolveu e coisas que as pessoas te elogiam por fazer bem?"),
        ("PELO QUE VOCÊ PODE SER PAGO? 💰", "Pense em habilidades ou serviços que têm valor no mercado e pelos quais alguém pagaria. Isso pode estar relacionado ao seu trabalho atual, a um hobby ou a algo que você gostaria de desenvolver."),
        ("DO QUE O MUNDO PRECISA (NA SUA OPINIÃO)? 🌍", "Pense nos problemas que você vê no mundo, nas necessidades da sua comunidade ou em causas que te tocam. Como você poderia contribuir para tornar o mundo um lugar melhor?")
    ]
    chaves_ikigai = ["ama_fazer", "bom_em", "pode_ser_pago", "mundo_precisa"]

    for i, (pergunta, descricao) in enumerate(ikigai_perguntas):
        display_html(f"<h3 style='color:#2e7d32; margin-top:25px;'>{pergunta}</h3>{styled_text(descricao, size='15px')}")
        respostas_ikigai[chaves_ikigai[i]] = get_user_input(f"Descreva '{pergunta.lower().split('?')[0]}':")
        display_html(styled_section_break())


    clear_output(wait=True)
    display_html(styled_title("📝 Suas Reflexões sobre o IKIGAI 📝", level="h2", color="#4CAF50"))
    html_resumo = "<div style='background-color: #e8f5e9; padding: 15px; border-radius: 8px;'>"
    html_resumo += styled_text("Aqui está um resumo das suas respostas:", size="18px", weight="bold", color="#1b5e20")
    html_resumo += f"<p><strong>1. O QUE VOCÊ AMA FAZER:</strong><br><i style='color:#388e3c;'>'{respostas_ikigai['ama_fazer']}'</i></p>"
    html_resumo += f"<p><strong>2. NO QUE VOCÊ É BOM:</strong><br><i style='color:#388e3c;'>'{respostas_ikigai['bom_em']}'</i></p>"
    html_resumo += f"<p><strong>3. PELO QUE VOCÊ PODE SER PAGO:</strong><br><i style='color:#388e3c;'>'{respostas_ikigai['pode_ser_pago']}'</i></p>"
    html_resumo += f"<p><strong>4. DO QUE O MUNDO PRECISA:</strong><br><i style='color:#388e3c;'>'{respostas_ikigai['mundo_precisa']}'</i></p>"
    html_resumo += "</div>"
    display_html(html_resumo)

    display_html(styled_title("🔗 Analisando as Interseções do seu IKIGAI 🔗", level="h2", color="#66bb6a", margin_top="30px"))
    intersecoes_html = "<div style='line-height: 1.6;'>"
    intersecoes_html += f"""
    <div style='margin-bottom:15px; padding:10px; border-left: 4px solid #ffb74d; background-color:#fff3e0;'>
    <h4 style='color:#f57c00; margin-top:0;'>🌟 PAIXÃO (O que você ama + No que você é bom):</h4>
    <p>Isto é o que te move e onde seus talentos brilham naturalmente.<br>
    Reflita sobre como <i>'{respostas_ikigai['ama_fazer']}'</i> se une com <i>'{respostas_ikigai['bom_em']}'</i>.<br>
    <small><i>Satisfação, mas talvez sem utilidade ou renda.</i></small></p></div>
    """
    intersecoes_html += f"""
    <div style='margin-bottom:15px; padding:10px; border-left: 4px solid #4dd0e1; background-color:#e0f7fa;'>
    <h4 style='color:#00acc1; margin-top:0;'>🎯 MISSÃO (O que você ama + O que o mundo precisa):</h4>
    <p>Aqui reside o seu desejo de contribuir para algo maior, fazendo o que te alegra.<br>
    Pense em como <i>'{respostas_ikigai['ama_fazer']}'</i> pode atender a <i>'{respostas_ikigai['mundo_precisa']}'</i>.<br>
    <small><i>Alegria e realização, mas talvez sem habilidades desenvolvidas ou renda.</i></small></p></div>
    """
    intersecoes_html += f"""
    <div style='margin-bottom:15px; padding:10px; border-left: 4px solid #ba68c8; background-color:#f3e5f5;'>
    <h4 style='color:#8e24aa; margin-top:0;'>💼 PROFISSÃO (No que você é bom + Pelo que você pode ser pago):</h4>
    <p>Esta é a sua carreira, onde suas habilidades são recompensadas financeiramente.<br>
    Considere como <i>'{respostas_ikigai['bom_em']}'</i> se alinha com <i>'{respostas_ikigai['pode_ser_pago']}'</i>.<br>
    <small><i>Carreira confortável, mas pode faltar paixão ou propósito.</i></small></p></div>
    """
    intersecoes_html += f"""
    <div style='margin-bottom:15px; padding:10px; border-left: 4px solid #7986cb; background-color:#e8eaf6;'>
    <h4 style='color:#3f51b5; margin-top:0;'>🌍 VOCAÇÃO (O que o mundo precisa + Pelo que você pode ser pago):</h4>
    <p>Neste ponto, você atende a uma necessidade do mundo e é remunerado por isso.<br>
    Analise como <i>'{respostas_ikigai['mundo_precisa']}'</i> se conecta com <i>'{respostas_ikigai['pode_ser_pago']}'</i>.<br>
    <small><i>Trabalho útil, mas pode haver incerteza ou falta de satisfação.</i></small></p></div>
    """
    intersecoes_html += "</div>"
    display_html(intersecoes_html)

    display_html(f"""
    <div style='background-color: #c8e6c9; border: 2px dashed #388e3c; padding: 20px; margin-top: 25px; border-radius: 8px; text-align:center;'>
        <h3 style='color: #1b5e20; margin-top:0;'>💡 SEU IKIGAI 💡</h3>
        <p style='font-size:17px;'>Seu IKIGAI é o ponto central onde todas essas quatro áreas se encontram:</p>
        <ul style='list-style-type: "✔️ "; padding-left: 20px; display: inline-block; text-align: left; font-size:16px;'>
            <li>Você AMA fazer isso.</li>
            <li>Você é BOM nisso.</li>
            <li>O MUNDO precisa disso.</li>
            <li>Você pode SER PAGO por isso.</li>
        </ul>
        <p style='font-size:16px; margin-top:15px;'>Busque atividades ou caminhos que integrem o máximo possível dessas quatro dimensões.<br>
        Por exemplo, como você pode usar o que você <strong>AMA FAZER</strong> ('{respostas_ikigai['ama_fazer']}') e suas <strong>HABILIDADES</strong> ('{respostas_ikigai['bom_em']}') para atender a uma <strong>NECESSIDADE DO MUNDO</strong> ('{respostas_ikigai['mundo_precisa']}') de uma forma que também possa te <strong>REMUNERAR</strong> ('{respostas_ikigai['pode_ser_pago']}')?</p>
    </div>
    """)
    display_html(styled_text("<br>Esta é uma jornada de autoconhecimento contínua. Use essas reflexões como um mapa para explorar e construir uma vida com mais propósito!", size="16px", weight="bold", color="#333"))
    display_html(styled_section_break())


def modulo_disc():
    """Conduz o usuário através do questionário DISC e apresenta o perfil com HTML."""
    clear_output(wait=True)
    display_html(styled_title("🧠 Descobrindo seu Perfil Comportamental (DISC) 🧠", level="h1", color="#FF5722"))
    disc_intro = """
    <div style='background-color: #fff3e0; padding: 15px; border-radius: 8px; margin-bottom: 20px;'>
    <p style='font-size:17px;'>A metodologia DISC descreve quatro estilos comportamentais principais:</p>
    <ul style='font-size:16px; list-style-position: inside;'>
        <li><strong>D - Dominância:</strong> Focado em resultados, direto, competitivo.</li>
        <li><strong>I - Influência:</strong> Comunicativo, otimista, entusiasmado, sociável.</li>
        <li><strong>S - Estabilidade (Steadiness):</strong> Paciente, calmo, bom ouvinte, persistente.</li>
        <li><strong>C - Conformidade (Conscientiousness):</strong> Preciso, analítico, detalhista, lógico.</li>
    </ul>
    <p style='font-size:16px;'>Responda às seguintes perguntas escolhendo a afirmação que <strong>MAIS</strong> se aplica a você em cada grupo.<br>
    Não há respostas certas ou erradas. Seja honesto(a) consigo mesmo(a).</p>
    </div>
    """
    display_html(disc_intro)

    pontos = {"D": 0, "I": 0, "S": 0, "C": 0}
    # ... (Mantendo a lista 'perguntas_disc' da v3 - ela é longa, então vou omiti-la aqui para brevidade, mas ela deve estar aqui)
    perguntas_disc = [
        # Bloco 1: Preferências Gerais e Estilo Pessoal (5 perguntas)
        {
            "pergunta": "Grupo 1: Em geral, eu sou mais:",
            "opcoes": {
                "a": ("Assertivo(a) e gosto de desafios.", "D"),
                "b": ("Sociável e gosto de interagir com pessoas.", "I"),
                "c": ("Calmo(a) e gosto de ambientes estáveis.", "S"),
                "d": ("Cuidadoso(a) e gosto de seguir regras.", "C")
            }
        },
        {
            "pergunta": "Grupo 2: Minha principal motivação é:",
            "opcoes": {
                "a": ("Alcançar resultados e superar metas.", "D"),
                "b": ("Ser reconhecido(a) e apreciado(a).", "I"),
                "c": ("Ter segurança e harmonia.", "S"),
                "d": ("Fazer as coisas corretamente e com precisão.", "C")
            }
        },
        {
            "pergunta": "Grupo 3: As pessoas geralmente me descrevem como:",
            "opcoes": {
                "a": ("Decidido(a) e direto(a).", "D"),
                "b": ("Entusiasmado(a) e comunicativo(a).", "I"),
                "c": ("Paciente e bom(a) ouvinte.", "S"),
                "d": ("Organizado(a) e detalhista.", "C")
            }
        },
        {
            "pergunta": "Grupo 4: Eu me sinto mais energizado(a) quando:",
            "opcoes": {
                "a": ("Estou no comando e enfrentando desafios.", "D"),
                "b": ("Estou colaborando e socializando com outros.", "I"),
                "c": ("Estou ajudando os outros e mantendo a paz.", "S"),
                "d": ("Estou analisando informações e resolvendo problemas complexos.", "C")
            }
        },
        {
            "pergunta": "Grupo 5: Meu maior medo é provavelmente:",
            "opcoes": {
                "a": ("Perder o controle ou ser explorado(a).", "D"),
                "b": ("Ser rejeitado(a) ou desaprovado(a) socialmente.", "I"),
                "c": ("Perder a segurança ou enfrentar mudanças repentinas.", "S"),
                "d": ("Ser criticado(a) por erros ou falta de qualidade.", "C")
            }
        },

        # Bloco 2: Tomada de Decisão e Resolução de Problemas (5 perguntas)
        {
            "pergunta": "Grupo 6: Quando tomo decisões, eu tendo a ser:",
            "opcoes": {
                "a": ("Rápido(a) e decidido(a), focado(a) no objetivo.", "D"),
                "b": ("Intuitivo(a) e busco opiniões, mas gosto de inspirar.", "I"),
                "c": ("Cauteloso(a), consulto os outros e busco consenso.", "S"),
                "d": ("Analítico(a), baseado(a) em fatos e dados.", "C")
            }
        },
        {
            "pergunta": "Grupo 7: Ao enfrentar um problema, minha primeira reação é:",
            "opcoes": {
                "a": ("Agir rapidamente para resolvê-lo.", "D"),
                "b": ("Conversar sobre ele e buscar soluções criativas com outros.", "I"),
                "c": ("Manter a calma e pensar sobre o impacto nas pessoas.", "S"),
                "d": ("Analisar a causa raiz e planejar cuidadosamente.", "C")
            }
        },
        {
            "pergunta": "Grupo 8: Em situações de pressão, eu costumo:",
            "opcoes": {
                "a": ("Me tornar mais focado(a) e determinado(a).", "D"),
                "b": ("Buscar apoio social e manter o otimismo.", "I"),
                "c": ("Manter a compostura e buscar estabilidade.", "S"),
                "d": ("Me concentrar nos detalhes para evitar erros.", "C")
            }
        },
        {
            "pergunta": "Grupo 9: Prefiro um ambiente de trabalho que seja:",
            "opcoes": {
                "a": ("Competitivo e orientado para resultados.", "D"),
                "b": ("Amigável, colaborativo e estimulante.", "I"),
                "c": ("Estável, previsível e harmonioso.", "S"),
                "d": ("Organizado, com regras claras e foco na qualidade.", "C")
            }
        },
        {
            "pergunta": "Grupo 10: Ao receber feedback, eu prefiro que seja:",
            "opcoes": {
                "a": ("Direto e focado nos resultados.", "D"),
                "b": ("Positivo e encorajador, com reconhecimento.", "I"),
                "c": ("Gentil, construtivo e focado no processo.", "S"),
                "d": ("Específico, baseado em fatos e com sugestões de melhoria.", "C")
            }
        },

        # Bloco 3: Ritmo de Trabalho e Comunicação (5 perguntas)
        {
            "pergunta": "Grupo 11: Meu ritmo de trabalho é geralmente:",
            "opcoes": {
                "a": ("Acelerado e focado em múltiplas metas.", "D"),
                "b": ("Animado e flexível, adaptando-me conforme necessário.", "I"),
                "c": ("Constante, metódico e focado em uma tarefa por vez.", "S"),
                "d": ("Preciso, sistemático e orientado a detalhes.", "C")
            }
        },
        {
            "pergunta": "Grupo 12: Na comunicação, eu valorizo mais:",
            "opcoes": {
                "a": ("Objetividade e ir direto ao ponto.", "D"),
                "b": ("Entusiasmo e capacidade de persuasão.", "I"),
                "c": ("Empatia e escuta ativa.", "S"),
                "d": ("Clareza, precisão e dados concretos.", "C")
            }
        },
        {
            "pergunta": "Grupo 13: Quando preciso convencer alguém, eu geralmente:",
            "opcoes": {
                "a": ("Apresento argumentos fortes e assertivos.", "D"),
                "b": ("Uso meu carisma e entusiasmo para inspirar.", "I"),
                "c": ("Construo confiança e mostro os benefícios para todos.", "S"),
                "d": ("Mostro dados, lógica e os prós e contras detalhadamente.", "C")
            }
        },
        {
            "pergunta": "Grupo 14: Eu me sinto mais confortável quando:",
            "opcoes": {
                "a": ("Tenho autonomia e posso controlar as situações.", "D"),
                "b": ("Sou reconhecido(a) e posso me expressar livremente.", "I"),
                "c": ("Tenho segurança, rotina e relacionamentos harmoniosos.", "S"),
                "d": ("Tenho clareza nas expectativas e nos procedimentos.", "C")
            }
        },
        {
            "pergunta": "Grupo 15: Em um projeto em grupo, eu costumo ser quem:",
            "opcoes": {
                "a": ("Assume a liderança e direciona as ações.", "D"),
                "b": ("Motiva o grupo e facilita a comunicação.", "I"),
                "c": ("Apoia os colegas e garante um bom ambiente.", "S"),
                "d": ("Organiza as tarefas e verifica a qualidade do trabalho.", "C")
            }
        },

        # Bloco 4: Relacionamento Interpessoal e Reação a Mudanças (5 perguntas)
        {
            "pergunta": "Grupo 16: Quando conheço novas pessoas, eu:",
            "opcoes": {
                "a": ("Sou direto(a) e foco em objetivos comuns.", "D"),
                "b": ("Sou aberto(a), falante e busco conexões.", "I"),
                "c": ("Sou reservado(a) no início, mas amigável e leal.", "S"),
                "d": ("Sou observador(a) e analiso a situação antes de interagir muito.", "C")
            }
        },
        {
            "pergunta": "Grupo 17: Minha reação a mudanças inesperadas é geralmente:",
            "opcoes": {
                "a": ("Vê-las como um desafio e me adaptar rapidamente para liderar.", "D"),
                "b": ("Ficar animado(a) com a novidade e explorar as possibilidades.", "I"),
                "c": ("Sentir um desconforto inicial e precisar de tempo para me ajustar.", "S"),
                "d": ("Analisar os impactos e buscar entender as novas regras/processos.", "C")
            }
        },
        {
            "pergunta": "Grupo 18: Eu aprendo melhor quando:",
            "opcoes": {
                "a": ("Posso experimentar e ver resultados práticos.", "D"),
                "b": ("Há interação, discussão e um ambiente estimulante.", "I"),
                "c": ("O processo é claro, passo a passo e posso praticar com calma.", "S"),
                "d": ("Tenho acesso a informações detalhadas e posso analisar por mim mesmo(a).", "C")
            }
        },
        {
            "pergunta": "Grupo 19: O que mais me frustra no comportamento dos outros é:",
            "opcoes": {
                "a": ("Indecisão e falta de foco em resultados.", "D"),
                "b": ("Pessimismo e falta de entusiasmo ou colaboração.", "I"),
                "c": ("Impaciência, agressividade ou desconsideração pelos sentimentos alheios.", "S"),
                "d": ("Desorganização, informações incorretas ou falta de atenção aos detalhes.", "C")
            }
        },
        {
            "pergunta": "Grupo 20: Se eu tivesse que escolher um lema, seria algo como:",
            "opcoes": {
                "a": ("'Resultados agora!' ou 'Feito é melhor que perfeito'.", "D"),
                "b": ("'Juntos somos mais fortes!' ou 'A vida é uma festa!'.", "I"),
                "c": ("'Com calma e paciência se vai longe' ou 'A união faz a força'.", "S"),
                "d": ("'Se vale a pena fazer, vale a pena fazer bem feito' ou 'Precisão é tudo'.", "C")
            }
        }
    ]

    for i, item in enumerate(perguntas_disc):
        clear_output(wait=True) # Limpa a saída para mostrar apenas a pergunta atual
        display_html(styled_title(f"Pergunta {i+1} de {len(perguntas_disc)}", level="h3", color="#FF5722"))
        display_html(styled_question_group(item['pergunta'], item['opcoes']))
        while True:
            resposta_usuario = get_user_input("Escolha uma alternativa (a, b, c ou d):").lower()
            if resposta_usuario in item['opcoes']:
                perfil_escolhido = item['opcoes'][resposta_usuario][1]
                pontos[perfil_escolhido] += 1
                break
            else:
                display_html(styled_text("Opção inválida. Por favor, escolha entre a, b, c ou d.", color="red"))
        if i < len(perguntas_disc) -1:
             display_html("<p style='text-align:center; font-style:italic; color: #777;'>Próxima pergunta...</p>")
             # time.sleep(0.5) # Pequena pausa opcional

    clear_output(wait=True)
    display_html(styled_title("📊 Seu Resultado DISC 📊", level="h2", color="#FF5722"))

    perfil_predominante = max(pontos, key=pontos.get)
    maior_pontuacao = pontos[perfil_predominante]
    perfis_empatados = [perfil for perfil, pontuacao in pontos.items() if pontuacao == maior_pontuacao]

    resultado_html = f"<div style='background-color:#fff3e0; padding:15px; border-radius:8px;'>"
    resultado_html += styled_text(f"<strong>Pontuações:</strong> D={pontos['D']}, I={pontos['I']}, S={pontos['S']}, C={pontos['C']}", size="18px", color="#e65100")

    if len(perfis_empatados) > 1:
        resultado_html += styled_text(f"Você apresentou características fortes em mais de um perfil: <strong>{', '.join(perfis_empatados)}</strong>.", size="17px")
        resultado_html += styled_text("É comum ter traços de múltiplos perfis. Abaixo, uma descrição geral de cada um deles para sua reflexão:", size="16px")
        for perfil_empatado in perfis_empatados:
            resultado_html += get_descricao_disc_html(perfil_empatado)
    else:
        resultado_html += styled_text(f"Seu perfil comportamental predominante parece ser: <strong>{perfil_predominante}</strong>", size="17px")
        resultado_html += get_descricao_disc_html(perfil_predominante)
    resultado_html += "</div>"
    display_html(resultado_html)

    display_html(styled_text("<br><em>Lembre-se que este é um teste simplificado. Para uma análise aprofundada, procure um profissional certificado.</em>", size="15px", color="#555"))
    display_html(styled_section_break())

def get_descricao_disc_html(perfil):
    """Retorna a descrição HTML de um perfil DISC específico."""
    descricoes = {
        "D": {
            "titulo": "🟥 Dominância (D)",
            "cor_borda": "#d32f2f",
            "texto": """Pessoas com alta Dominância são geralmente diretas, assertivas, competitivas e focadas em resultados.
                        Gostam de desafios, tomam decisões rapidamente e buscam controle sobre as situações.""",
            "pontos_fortes": "Liderança, determinação, foco em resultados, resolução de problemas, iniciativa.",
            "pontos_atencao": "Podem parecer impacientes, autoritários, insensíveis ou excessivamente exigentes."
        },
        "I": {
            "titulo": "🟨 Influência (I)",
            "cor_borda": "#fbc02d",
            "texto": """Indivíduos com alta Influência são comunicativos, otimistas, persuasivos e sociáveis.
                        Gostam de interagir com pessoas, inspirar os outros e trabalhar em equipe. Valorizam o reconhecimento.""",
            "pontos_fortes": "Entusiasmo, habilidade de comunicação, otimismo, persuasão, construção de relacionamentos.",
            "pontos_atencao": "Podem ter dificuldade com detalhes, organização, seguir rotinas ou cumprir prazos se não estiverem motivados. Podem ser vistos como impulsivos ou superficiais."
        },
        "S": {
            "titulo": "🟩 Estabilidade (S - Steadiness)",
            "cor_borda": "#388e3c",
            "texto": """Pessoas com alta Estabilidade são calmas, pacientes, leais, consistentes e boas ouvintes.
                        Valorizam a segurança, a harmonia nos relacionamentos e ambientes previsíveis. São colaborativas.""",
            "pontos_fortes": "Cooperação, persistência, confiabilidade, lealdade, paciência, bom ouvinte.",
            "pontos_atencao": "Podem resistir a mudanças, ter dificuldade em dizer 'não', evitar conflitos ou demorar para tomar decisões que envolvam riscos."
        },
        "C": {
            "titulo": "🟦 Conformidade (C - Conscientiousness)",
            "cor_borda": "#1976d2",
            "texto": """Indivíduos com alta Conformidade são precisos, analíticos, organizados, lógicos e focados em qualidade e regras.
                        Gostam de seguir procedimentos, prestar atenção aos detalhes e basear decisões em fatos e dados.""",
            "pontos_fortes": "Precisão, disciplina, pensamento crítico, organização, atenção aos detalhes, planejamento.",
            "pontos_atencao": "Podem ser excessivamente críticos, perfeccionistas, ter dificuldade em tomar decisões sem todos os dados ou parecer distantes e formais."
        }
    }
    d = descricoes[perfil]
    return f"""
    <div style='border: 1px solid {d["cor_borda"]}; border-left: 5px solid {d["cor_borda"]}; background-color: #fafafa; padding: 15px; margin-top: 15px; border-radius: 5px;'>
        <h4 style='color:{d["cor_borda"]}; margin-top:0;'>{d["titulo"]}</h4>
        <p>{d["texto"]}</p>
        <p><strong>Pontos fortes:</strong> {d["pontos_fortes"]}</p>
        <p><strong>Pontos de atenção:</strong> {d["pontos_atencao"]}</p>
    </div>
    """

def chatbot():
    """Função principal que executa o chatbot com interface HTML."""
    # import time # Para usar no módulo DISC se desejar uma pausa
    exibir_boas_vindas()
    while True:
        escolha = exibir_menu_principal()
        if escolha == 1:
            modulo_ikigai()
        elif escolha == 2:
            modulo_disc()
        elif escolha == 3:
            clear_output(wait=True)
            display_html(styled_title("👋 Até a próxima! 👋", level="h2", color="#007bff"))
            display_html(styled_text("Obrigado por usar nosso assistente de autoconhecimento. Esperamos que tenha sido útil!", size="18px"))
            break
        display_html("<div style='text-align:center; margin-top:20px;'><hr></div>") # Divisor antes de mostrar o menu novamente
        # Pausa para o usuário ler, antes de reimprimir o menu
        get_user_input("Pressione Enter para voltar ao menu principal...")
        clear_output(wait=True) # Limpa a saída antes de mostrar o menu novamente
        exibir_boas_vindas() # Reexibe boas-vindas para um refresh visual

# Iniciar o chatbot
if __name__ == "__main__":
    chatbot()
# Out:
#     <div style='background-color: #e7f3fe; border-left: 6px solid #2196F3; padding: 20px; margin-bottom: 20px; border-radius: 5px;'>
#         <h1 style='color: #1976D2; margin-top:0;'>🌟 Bem-vindo(a) ao Assistente de Autoconhecimento! 🌟</h1>
#         <p style='font-size: 18px; color: #333;'>Olá! Estou aqui para te ajudar a refletir sobre seu <strong>propósito de vida (IKIGAI)</strong>
#         e a identificar seu <strong>perfil comportamental (DISC)</strong>.</p>
#         <p style='font-size: 16px; color: #555;'>Vamos começar essa jornada juntos?</p>
#     </div>
# <h2 style='color:#ff9800; margin-top:20px; margin-bottom:15px; border-bottom: 2px solid #ff9800; padding-bottom: 5px;'>Como posso te ajudar hoje?</h2>
#     <ul style='list-style-type: none; padding-left: 0; font-size: 18px;'>
#         <li style='margin-bottom: 10px; background-color:#f0f0f0; padding:10px; border-radius:5px;'><strong>1.</strong> 🧘 Encontrar meu IKIGAI (Propósito de Vida)</li>
# ...
